# %% [markdown]
# # PPT 퀴즈

# %% [markdown]
# #### customerdata를 활용하여 scatter plot 그려보기 (x축:DEVICECOUNT / y축:PRODUCTAGE / 컬러:CUSTTYPE)

# %%
import seaborn as sns
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM customerdata', engine1)

# %%
customerData.head(3)
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  E11917  3516.500000    2          5.5    2.087540  Big-Screen-lover
# 1  E16075  3418.048887    2          4.2    2.771469      Sleeping-dog
# 2  E16221  3408.300000    2          5.0    1.988682  Big-Screen-lover

# %%
customerData["COLOR"]=np.where(customerData['CUSTTYPE']=='Big-Screen-lover',1,\
                              np.where(customerData['CUSTTYPE']=='Sleeping-dog',2,\
                                      np.where(customerData['CUSTTYPE']=='Early-bird',3,4)))

# %%
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  COLOR
# 0  E11917  3516.500000    2          5.5    2.087540  Big-Screen-lover      1
# 1  E16075  3418.048887    2          4.2    2.771469      Sleeping-dog      2
# 2  E16221  3408.300000    2          5.0    1.988682  Big-Screen-lover      1
# 3  E18145  3408.300000    2          4.9    1.521029  Big-Screen-lover      1
# 4  E19404  3764.940414    2          6.5    0.900000        Early-bird      3

# %%
customerData.plot.scatter(x='DEVICECOUNT',y='PRODUCTAGE',c='COLOR')

# %%
a=customerData.DEVICECOUNT
b=customerData.PRODUCTAGE
c=customerData.COLOR

# %%
plt.scatter(a,b,c=c)
plt.colorbar()

# %%
sns.lmplot(x='DEVICECOUNT', y = 'PRODUCTAGE', data = customerData, hue ='CUSTTYPE' )
